# %%
import numpy as np
import pandas as pd

# %%
a=np.array([10,20,30,40,50])
print("Array:",a)
print("Mean:",a.mean())
print("Reshaped 2D:",a.reshape(5,1))
print("Slice (index 1 to 3):",a[:4])
# Out:
# Array: [10 20 30 40 50]
# Mean: 30.0
# Reshaped 2D: [[10]
#  [20]
#  [30]
#  [40]
#  [50]]
# Slice (index 1 to 3): [10 20 30 40]

# %%
d={
    "Name":["Ram","Rohan","Raj"],
    "Marks":[80,78,69],
    "Branch":["CSE","ISE","AI"]
}

data=pd.DataFrame(d)
print(data)
# Out:
#     Name  Marks Branch
# 0    Ram     80    CSE
# 1  Rohan     78    ISE
# 2    Raj     69     AI

# %%
print("First 2 Rows\n",data.iloc[:2])
# Out:
# First 2 Rows
#      Name  Marks Branch
# 0    Ram     80    CSE
# 1  Rohan     78    ISE

# %%
data.iloc[:2]
# Out:
#     Name  Marks Branch
# 0    Ram     80    CSE
# 1  Rohan     78    ISE

# %%
print("Marks Column:\n",data["Marks"])
# Out:
# Marks Column:
#  0    80
# 1    78
# 2    69
# Name: Marks, dtype: int64

# %%
print("Row where Marks > 70:\n",data[data["Marks"]>70])
# Out:
# Row where Marks > 70:
#      Name  Marks Branch
# 0    Ram     80    CSE
# 1  Rohan     78    ISE
